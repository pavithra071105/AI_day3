# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithra071105/AI_day3/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
RANDOM_STATE = 42

# %%
url = "https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv"
data = pd.read_csv(url, sep='\t', header=None, names=['label', 'message'])

# %%
data['label_num'] = data['label'].map({'ham': 0, 'spam': 1})

# %%
TARGET_N = 2000
if len(data) < TARGET_N:
    raise ValueError(f"Dataset has only {len(data)} messages — need at least {TARGET_N}.")

# %%
prop = data['label'].value_counts(normalize=True)
n_spam = int(round(prop['spam'] * TARGET_N))
n_ham = TARGET_N - n_spam
sampled_spam = data[data['label']=='spam'].sample(n=n_spam, random_state=RANDOM_STATE)
sampled_ham  = data[data['label']=='ham'].sample(n=n_ham, random_state=RANDOM_STATE)
sampled = pd.concat([sampled_ham, sampled_spam]).sample(frac=1, random_state=RANDOM_STATE).reset_index(drop=True)

# %%
X = sampled['message']
y = sampled['label_num']
# first split out the test set of size 500
X_rest, X_test, y_rest, y_test = train_test_split(X, y, test_size=500, stratify=y, random_state=RANDOM_STATE)
# remaining 1500 will be training set
X_train, y_train = X_rest, y_rest

# %%
print("Train size:", len(X_train), "Test size:", len(X_test))
print("Spam ratio in train:", y_train.mean(), " Spam ratio in test:", y_test.mean())
# Out:
# Train size: 1500 Test size: 500
# Spam ratio in train: 0.134  Spam ratio in test: 0.134

# %%
tfidf = TfidfVectorizer(stop_words='english', max_features=3000)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf  = tfidf.transform(X_test)

# %%
model = LogisticRegression(max_iter=2000, random_state=RANDOM_STATE)
model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=2000, random_state=42)

# %%
y_pred = model.predict(X_test_tfidf)
acc = accuracy_score(y_test, y_pred)
print("\nModel Accuracy:", acc)
# Out:
# Model Accuracy: 0.916

# %%
print("\nCategories: ['Not Spam', 'Spam']\n")
sample_messages = X_test.reset_index(drop=True)[:300]   # first 30 test messages
sample_vectors = tfidf.transform(sample_messages)
probabilities = model.predict_proba(sample_vectors)
# Out:
# Categories: ['Not Spam', 'Spam']

# %%
for i, prob in enumerate(probabilities, start=1):
    spam_prob = prob[1]   # probability for class = 1 (spam)
    prediction = "SPAM" if spam_prob > 0.5 else "NOT SPAM"
    print(f"Email {i}: Sigmoid Output = {spam_prob:.4f} ({spam_prob*100:.1f}%) -> Prediction: {prediction}")
# Out:
# Email 1: Sigmoid Output = 0.0597 (6.0%) -> Prediction: NOT SPAM
# Email 2: Sigmoid Output = 0.0588 (5.9%) -> Prediction: NOT SPAM
# Email 3: Sigmoid Output = 0.0426 (4.3%) -> Prediction: NOT SPAM
# Email 4: Sigmoid Output = 0.0213 (2.1%) -> Prediction: NOT SPAM
# Email 5: Sigmoid Output = 0.0832 (8.3%) -> Prediction: NOT SPAM
# Email 6: Sigmoid Output = 0.0704 (7.0%) -> Prediction: NOT SPAM
# Email 7: Sigmoid Output = 0.0382 (3.8%) -> Prediction: NOT SPAM
# Email 8: Sigmoid Output = 0.6879 (68.8%) -> Prediction: SPAM
# Email 9: Sigmoid Output = 0.1359 (13.6%) -> Prediction: NOT SPAM
# Email 10: Sigmoid Output = 0.0496 (5.0%) -> Prediction: NOT SPAM
# Email 11: Sigmoid Output = 0.0652 (6.5%) -> Prediction: NOT SPAM
# Email 12: Sigmoid Output = 0.0913 (9.1%) -> Prediction: NOT SPAM
# Email 13: Sigmoid Output = 0.5395 (54.0%) -> Prediction: SPAM
# Email 14: Sigmoid Output = 0.0880 (8.8%) -> Prediction: NOT SPAM
# Email 15: Sigmoid Output = 0.0513 (5.1%) -> Prediction: NOT SPAM
# Email 16: Sigmoid Output = 0.0845 (8.5%) -> Prediction: NOT SPAM
# Email 17: Sigmoid Output = 0.0307 (3.1%) -> Prediction: NOT SPAM
# Email 18: Sigmoid Output = 0.8478 (84.8%) -> Prediction: SPAM
# Email 19: Sigmoid Output = 0.6215 (62.1%) -> Prediction: SPAM
# Email 20: Sigmoid Output = 0.0825 (8.3%) -> Prediction: NOT SPAM
# Email 21: Sigmoid Output = 0.0550 (5.5%) -> Prediction: NOT SPAM
# Email 22: Sigmoid Output = 0.0719 (7.2%) -> Prediction: NOT SPAM
# Email 23: Sigmoid Output = 0.0701 (7.0%) -> Prediction: NOT SPAM
# Email 24: Sigmoid Output = 0.0949 (9.5%) -> Prediction: NOT SPAM
# Email 25: Sigmoid Output = 0.0841 (8.4%) -> Prediction: NOT SPAM
# Email 26: Sigmoid Output = 0.0485 (4.9%) -> Prediction: NOT SPAM
# Email 27: Sigmoid Output = 0.0787 (7.9%) -> Prediction: NOT SPAM
# Email 28: Sigmoid Output = 0.1062 (10.6%) -> Prediction: NOT SPAM
# Email 29: Sigmoid Output = 0.0921 (9.2%) -> Prediction: NOT SPAM
# Email 30: Sigmoid Output = 0.0910 (9.1%) -> Prediction: NOT SPAM
# Email 31: Sigmoid Output = 0.1119 (11.2%) -> Prediction: NOT SPAM
# Email 32: Sigmoid Output = 0.0387 (3.9%) -> Prediction: NOT SPAM
# Email 33: Sigmoid Output = 0.0475 (4.7%) -> Prediction: NOT SPAM
# Email 34: Sigmoid Output = 0.0703 (7.0%) -> Prediction: NOT SPAM
# Email 35: Sigmoid Output = 0.0674 (6.7%) -> Prediction: NOT SPAM
# Email 36: Sigmoid Output = 0.0598 (6.0%) -> Prediction: NOT SPAM
# Email 37: Sigmoid Output = 0.0880 (8.8%) -> Prediction: NOT SPAM
# Email 38: Sigmoid Output = 0.0857 (8.6%) -> Prediction: NOT SPAM
# Email 39: Sigmoid Output = 0.0814 (8.1%) -> Prediction: NOT SPAM
# Email 40: Sigmoid Output = 0.0699 (7.0%) -> Prediction: NOT SPAM
# Email 41: Sigmoid Output = 0.0393 (3.9%) -> Prediction: NOT SPAM
# Email 42: Sigmoid Output = 0.0935 (9.4%) -> Prediction: NOT SPAM
# Email 43: Sigmoid Output = 0.0901 (9.0%) -> Prediction: NOT SPAM
# Email 44: Sigmoid Output = 0.0465 (4.6%) -> Prediction: NOT SPAM
# Email 45: Sigmoid Output = 0.0894 (8.9%) -> Prediction: NOT SPAM
# Email 46: Sigmoid Output = 0.0631 (6.3%) -> Prediction: NOT SPAM
# Email 47: Sigmoid Output = 0.0826 (8.3%) -> Prediction: NOT SPAM
# Email 48: Sigmoid Output = 0.0873 (8.7%) -> Prediction: NOT SPAM
# Email 49: Sigmoid Output = 0.1506 (15.1%) -> Prediction: NOT SPAM
# Email 50: Sigmoid Output = 0.3988 (39.9%) -> Prediction: NOT SPAM
# Email 51: Sigmoid Output = 0.0864 (8.6%) -> Prediction: NOT SPAM
# Email 52: Sigmoid Output = 0.1038 (10.4%) -> Prediction: NOT SPAM
# Email 53: Sigmoid Output = 0.1165 (11.7%) -> Prediction: NOT SPAM
# Email 54: Sigmoid Output = 0.0820 (8.2%) -> Prediction: NOT SPAM
# Email 55: Sigmoid Output = 0.0484 (4.8%) -> Prediction: NOT SPAM
# Email 56: Sigmoid Output = 0.7656 (76.6%) -> Prediction: SPAM
# Email 57: Sigmoid Output = 0.0996 (10.0%) -> Prediction: NOT SPAM
# Email 58: Sigmoid Output = 0.1027 (10.3%) -> Prediction: NOT SPAM
# Email 59: Sigmoid Output = 0.0661 (6.6%) -> Prediction: NOT SPAM
# Email 60: Sigmoid Output = 0.1118 (11.2%) -> Prediction: NOT SPAM
# Email 61: Sigmoid Output = 0.0865 (8.6%) -> Prediction: NOT SPAM
# Email 62: Sigmoid Output = 0.6575 (65.8%) -> Prediction: SPAM
# Email 63: Sigmoid Output = 0.0258 (2.6%) -> Prediction: NOT SPAM
# Email 64: Sigmoid Output = 0.0686 (6.9%) -> Prediction: NOT SPAM
# Email 65: Sigmoid Output = 0.0258 (2.6%) -> Prediction: NOT SPAM
# Email 66: Sigmoid Output = 0.0608 (6.1%) -> Prediction: NOT SPAM
# Email 67: Sigmoid Output = 0.4042 (40.4%) -> Prediction: NOT SPAM
# Email 68: Sigmoid Output = 0.0710 (7.1%) -> Prediction: NOT SPAM
# Email 69: Sigmoid Output = 0.0417 (4.2%) -> Prediction: NOT SPAM
# Email 70: Sigmoid Output = 0.0607 (6.1%) -> Prediction: NOT SPAM
# Email 71: Sigmoid Output = 0.6294 (62.9%) -> Prediction: SPAM
# Email 72: Sigmoid Output = 0.0521 (5.2%) -> Prediction: NOT SPAM
# Email 73: Sigmoid Output = 0.0372 (3.7%) -> Prediction: NOT SPAM
# Email 74: Sigmoid Output = 0.0625 (6.3%) -> Prediction: NOT SPAM
# Email 75: Sigmoid Output = 0.8094 (80.9%) -> Prediction: SPAM
# Email 76: Sigmoid Output = 0.1030 (10.3%) -> Prediction: NOT SPAM
# Email 77: Sigmoid Output = 0.0667 (6.7%) -> Prediction: NOT SPAM
# Email 78: Sigmoid Output = 0.0705 (7.0%) -> Prediction: NOT SPAM
# Email 79: Sigmoid Output = 0.3448 (34.5%) -> Prediction: NOT SPAM
# Email 80: Sigmoid Output = 0.0520 (5.2%) -> Prediction: NOT SPAM
# Email 81: Sigmoid Output = 0.0298 (3.0%) -> Prediction: NOT SPAM
# Email 82: Sigmoid Output = 0.0717 (7.2%) -> Prediction: NOT SPAM
# Email 83: Sigmoid Output = 0.0454 (4.5%) -> Prediction: NOT SPAM
# Email 84: Sigmoid Output = 0.0563 (5.6%) -> Prediction: NOT SPAM
# Email 85: Sigmoid Output = 0.0674 (6.7%) -> Prediction: NOT SPAM
# Email 86: Sigmoid Output = 0.0820 (8.2%) -> Prediction: NOT SPAM
# Email 87: Sigmoid Output = 0.0714 (7.1%) -> Prediction: NOT SPAM
# Email 88: Sigmoid Output = 0.1665 (16.7%) -> Prediction: NOT SPAM
# Email 89: Sigmoid Output = 0.0867 (8.7%) -> Prediction: NOT SPAM
# Email 90: Sigmoid Output = 0.0568 (5.7%) -> Prediction: NOT SPAM
# Email 91: Sigmoid Output = 0.0665 (6.7%) -> Prediction: NOT SPAM
# Email 92: Sigmoid Output = 0.0302 (3.0%) -> Prediction: NOT SPAM
# Email 93: Sigmoid Output = 0.0975 (9.7%) -> Prediction: NOT SPAM
# Email 94: Sigmoid Output = 0.7914 (79.1%) -> Prediction: SPAM
# Email 95: Sigmoid Output = 0.0295 (2.9%) -> Prediction: NOT SPAM
# Email 96: Sigmoid Output = 0.1013 (10.1%) -> Prediction: NOT SPAM
# Email 97: Sigmoid Output = 0.0673 (6.7%) -> Prediction: NOT SPAM
# Email 98: Sigmoid Output = 0.0642 (6.4%) -> Prediction: NOT SPAM
# Email 99: Sigmoid Output = 0.1514 (15.1%) -> Prediction: NOT SPAM
# Email 100: Sigmoid Output = 0.0734 (7.3%) -> Prediction: NOT SPAM
# Email 101: Sigmoid Output = 0.0781 (7.8%) -> Prediction: NOT SPAM
# Email 102: Sigmoid Output = 0.0541 (5.4%) -> Prediction: NOT SPAM
# Email 103: Sigmoid Output = 0.0630 (6.3%) -> Prediction: NOT SPAM
# Email 104: Sigmoid Output = 0.0439 (4.4%) -> Prediction: NOT SPAM
# Email 105: Sigmoid Output = 0.0751 (7.5%) -> Prediction: NOT SPAM
# Email 106: Sigmoid Output = 0.4439 (44.4%) -> Prediction: NOT SPAM
# Email 107: Sigmoid Output = 0.0855 (8.6%) -> Prediction: NOT SPAM
# Email 108: Sigmoid Output = 0.5483 (54.8%) -> Prediction: SPAM
# Email 109: Sigmoid Output = 0.0625 (6.3%) -> Prediction: NOT SPAM
# Email 110: Sigmoid Output = 0.0332 (3.3%) -> Prediction: NOT SPAM
# Email 111: Sigmoid Output = 0.3954 (39.5%) -> Prediction: NOT SPAM
# Email 112: Sigmoid Output = 0.0925 (9.3%) -> Prediction: NOT SPAM
# Email 113: Sigmoid Output = 0.0532 (5.3%) -> Prediction: NOT SPAM
# Email 114: Sigmoid Output = 0.0678 (6.8%) -> Prediction: NOT SPAM
# Email 115: Sigmoid Output = 0.3190 (31.9%) -> Prediction: NOT SPAM
# Email 116: Sigmoid Output = 0.0638 (6.4%) -> Prediction: NOT SPAM
# Email 117: Sigmoid Output = 0.0501 (5.0%) -> Prediction: NOT SPAM
# Email 118: Sigmoid Output = 0.0724 (7.2%) -> Prediction: NOT SPAM
# Email 119: Sigmoid Output = 0.0258 (2.6%) -> Prediction: NOT SPAM
# Email 120: Sigmoid Output = 0.0949 (9.5%) -> Prediction: NOT SPAM
# Email 121: Sigmoid Output = 0.0762 (7.6%) -> Prediction: NOT SPAM
# Email 122: Sigmoid Output = 0.0425 (4.3%) -> Prediction: NOT SPAM
# Email 123: Sigmoid Output = 0.0668 (6.7%) -> Prediction: NOT SPAM
# Email 124: Sigmoid Output = 0.0425 (4.3%) -> Prediction: NOT SPAM
# Email 125: Sigmoid Output = 0.0986 (9.9%) -> Prediction: NOT SPAM
# Email 126: Sigmoid Output = 0.0748 (7.5%) -> Prediction: NOT SPAM
# Email 127: Sigmoid Output = 0.0814 (8.1%) -> Prediction: NOT SPAM
# Email 128: Sigmoid Output = 0.0402 (4.0%) -> Prediction: NOT SPAM
# Email 129: Sigmoid Output = 0.4491 (44.9%) -> Prediction: NOT SPAM
# Email 130: Sigmoid Output = 0.0660 (6.6%) -> Prediction: NOT SPAM
# Email 131: Sigmoid Output = 0.1379 (13.8%) -> Prediction: NOT SPAM
# Email 132: Sigmoid Output = 0.0360 (3.6%) -> Prediction: NOT SPAM
# Email 133: Sigmoid Output = 0.0463 (4.6%) -> Prediction: NOT SPAM
# Email 134: Sigmoid Output = 0.0295 (2.9%) -> Prediction: NOT SPAM
# Email 135: Sigmoid Output = 0.0390 (3.9%) -> Prediction: NOT SPAM
# Email 136: Sigmoid Output = 0.0369 (3.7%) -> Prediction: NOT SPAM
# Email 137: Sigmoid Output = 0.0701 (7.0%) -> Prediction: NOT SPAM
# Email 138: Sigmoid Output = 0.0544 (5.4%) -> Prediction: NOT SPAM
# Email 139: Sigmoid Output = 0.0619 (6.2%) -> Prediction: NOT SPAM
# Email 140: Sigmoid Output = 0.1028 (10.3%) -> Prediction: NOT SPAM
# Email 141: Sigmoid Output = 0.1002 (10.0%) -> Prediction: NOT SPAM
# Email 142: Sigmoid Output = 0.0736 (7.4%) -> Prediction: NOT SPAM
# Email 143: Sigmoid Output = 0.0652 (6.5%) -> Prediction: NOT SPAM
# Email 144: Sigmoid Output = 0.0666 (6.7%) -> Prediction: NOT SPAM
# Email 145: Sigmoid Output = 0.0856 (8.6%) -> Prediction: NOT SPAM
# Email 146: Sigmoid Output = 0.1038 (10.4%) -> Prediction: NOT SPAM
# Email 147: Sigmoid Output = 0.0621 (6.2%) -> Prediction: NOT SPAM
# Email 148: Sigmoid Output = 0.0554 (5.5%) -> Prediction: NOT SPAM
# Email 149: Sigmoid Output = 0.0746 (7.5%) -> Prediction: NOT SPAM
# Email 150: Sigmoid Output = 0.0669 (6.7%) -> Prediction: NOT SPAM
# Email 151: Sigmoid Output = 0.1794 (17.9%) -> Prediction: NOT SPAM
# Email 152: Sigmoid Output = 0.0878 (8.8%) -> Prediction: NOT SPAM
# Email 153: Sigmoid Output = 0.0788 (7.9%) -> Prediction: NOT SPAM
# Email 154: Sigmoid Output = 0.0997 (10.0%) -> Prediction: NOT SPAM
# Email 155: Sigmoid Output = 0.0949 (9.5%) -> Prediction: NOT SPAM
# Email 156: Sigmoid Output = 0.0949 (9.5%) -> Prediction: NOT SPAM
# Email 157: Sigmoid Output = 0.0636 (6.4%) -> Prediction: NOT SPAM
# Email 158: Sigmoid Output = 0.3600 (36.0%) -> Prediction: NOT SPAM
# Email 159: Sigmoid Output = 0.0422 (4.2%) -> Prediction: NOT SPAM
# Email 160: Sigmoid Output = 0.0501 (5.0%) -> Prediction: NOT SPAM
# Email 161: Sigmoid Output = 0.0704 (7.0%) -> Prediction: NOT SPAM
# Email 162: Sigmoid Output = 0.0912 (9.1%) -> Prediction: NOT SPAM
# Email 163: Sigmoid Output = 0.0901 (9.0%) -> Prediction: NOT SPAM
# Email 164: Sigmoid Output = 0.0628 (6.3%) -> Prediction: NOT SPAM
# Email 165: Sigmoid Output = 0.5508 (55.1%) -> Prediction: SPAM
# Email 166: Sigmoid Output = 0.0589 (5.9%) -> Prediction: NOT SPAM
# Email 167: Sigmoid Output = 0.4343 (43.4%) -> Prediction: NOT SPAM
# Email 168: Sigmoid Output = 0.0781 (7.8%) -> Prediction: NOT SPAM
# Email 169: Sigmoid Output = 0.0855 (8.6%) -> Prediction: NOT SPAM
# Email 170: Sigmoid Output = 0.1739 (17.4%) -> Prediction: NOT SPAM
# Email 171: Sigmoid Output = 0.0885 (8.9%) -> Prediction: NOT SPAM
# Email 172: Sigmoid Output = 0.1434 (14.3%) -> Prediction: NOT SPAM
# Email 173: Sigmoid Output = 0.0737 (7.4%) -> Prediction: NOT SPAM
# Email 174: Sigmoid Output = 0.0886 (8.9%) -> Prediction: NOT SPAM
# Email 175: Sigmoid Output = 0.0514 (5.1%) -> Prediction: NOT SPAM
# Email 176: Sigmoid Output = 0.0700 (7.0%) -> Prediction: NOT SPAM
# Email 177: Sigmoid Output = 0.0736 (7.4%) -> Prediction: NOT SPAM
# Email 178: Sigmoid Output = 0.0646 (6.5%) -> Prediction: NOT SPAM
# Email 179: Sigmoid Output = 0.0667 (6.7%) -> Prediction: NOT SPAM
# Email 180: Sigmoid Output = 0.0645 (6.5%) -> Prediction: NOT SPAM
# Email 181: Sigmoid Output = 0.0642 (6.4%) -> Prediction: NOT SPAM
# Email 182: Sigmoid Output = 0.0708 (7.1%) -> Prediction: NOT SPAM
# Email 183: Sigmoid Output = 0.6555 (65.5%) -> Prediction: SPAM
# Email 184: Sigmoid Output = 0.0755 (7.5%) -> Prediction: NOT SPAM
# Email 185: Sigmoid Output = 0.0500 (5.0%) -> Prediction: NOT SPAM
# Email 186: Sigmoid Output = 0.2169 (21.7%) -> Prediction: NOT SPAM
# Email 187: Sigmoid Output = 0.0647 (6.5%) -> Prediction: NOT SPAM
# Email 188: Sigmoid Output = 0.0716 (7.2%) -> Prediction: NOT SPAM
# Email 189: Sigmoid Output = 0.0780 (7.8%) -> Prediction: NOT SPAM
# Email 190: Sigmoid Output = 0.0760 (7.6%) -> Prediction: NOT SPAM
# Email 191: Sigmoid Output = 0.0413 (4.1%) -> Prediction: NOT SPAM
# Email 192: Sigmoid Output = 0.0900 (9.0%) -> Prediction: NOT SPAM
# Email 193: Sigmoid Output = 0.0685 (6.8%) -> Prediction: NOT SPAM
# Email 194: Sigmoid Output = 0.0766 (7.7%) -> Prediction: NOT SPAM
# Email 195: Sigmoid Output = 0.0483 (4.8%) -> Prediction: NOT SPAM
# Email 196: Sigmoid Output = 0.0549 (5.5%) -> Prediction: NOT SPAM
# Email 197: Sigmoid Output = 0.0863 (8.6%) -> Prediction: NOT SPAM
# Email 198: Sigmoid Output = 0.0916 (9.2%) -> Prediction: NOT SPAM
# Email 199: Sigmoid Output = 0.0556 (5.6%) -> Prediction: NOT SPAM
# Email 200: Sigmoid Output = 0.0966 (9.7%) -> Prediction: NOT SPAM
# Email 201: Sigmoid Output = 0.0902 (9.0%) -> Prediction: NOT SPAM
# Email 202: Sigmoid Output = 0.0688 (6.9%) -> Prediction: NOT SPAM
# Email 203: Sigmoid Output = 0.0974 (9.7%) -> Prediction: NOT SPAM
# Email 204: Sigmoid Output = 0.0660 (6.6%) -> Prediction: NOT SPAM
# Email 205: Sigmoid Output = 0.0743 (7.4%) -> Prediction: NOT SPAM
# Email 206: Sigmoid Output = 0.0812 (8.1%) -> Prediction: NOT SPAM
# Email 207: Sigmoid Output = 0.3234 (32.3%) -> Prediction: NOT SPAM
# Email 208: Sigmoid Output = 0.0793 (7.9%) -> Prediction: NOT SPAM
# Email 209: Sigmoid Output = 0.0712 (7.1%) -> Prediction: NOT SPAM
# Email 210: Sigmoid Output = 0.0921 (9.2%) -> Prediction: NOT SPAM
# Email 211: Sigmoid Output = 0.0956 (9.6%) -> Prediction: NOT SPAM
# Email 212: Sigmoid Output = 0.5294 (52.9%) -> Prediction: SPAM
# Email 213: Sigmoid Output = 0.0876 (8.8%) -> Prediction: NOT SPAM
# Email 214: Sigmoid Output = 0.0424 (4.2%) -> Prediction: NOT SPAM
# Email 215: Sigmoid Output = 0.0576 (5.8%) -> Prediction: NOT SPAM
# Email 216: Sigmoid Output = 0.5493 (54.9%) -> Prediction: SPAM
# Email 217: Sigmoid Output = 0.0557 (5.6%) -> Prediction: NOT SPAM
# Email 218: Sigmoid Output = 0.0563 (5.6%) -> Prediction: NOT SPAM
# Email 219: Sigmoid Output = 0.2258 (22.6%) -> Prediction: NOT SPAM
# Email 220: Sigmoid Output = 0.0654 (6.5%) -> Prediction: NOT SPAM
# Email 221: Sigmoid Output = 0.0454 (4.5%) -> Prediction: NOT SPAM
# Email 222: Sigmoid Output = 0.0829 (8.3%) -> Prediction: NOT SPAM
# Email 223: Sigmoid Output = 0.0586 (5.9%) -> Prediction: NOT SPAM
# Email 224: Sigmoid Output = 0.0521 (5.2%) -> Prediction: NOT SPAM
# Email 225: Sigmoid Output = 0.0652 (6.5%) -> Prediction: NOT SPAM
# Email 226: Sigmoid Output = 0.0279 (2.8%) -> Prediction: NOT SPAM
# Email 227: Sigmoid Output = 0.4971 (49.7%) -> Prediction: NOT SPAM
# Email 228: Sigmoid Output = 0.1202 (12.0%) -> Prediction: NOT SPAM
# Email 229: Sigmoid Output = 0.0865 (8.6%) -> Prediction: NOT SPAM
# Email 230: Sigmoid Output = 0.0971 (9.7%) -> Prediction: NOT SPAM
# Email 231: Sigmoid Output = 0.0413 (4.1%) -> Prediction: NOT SPAM
# Email 232: Sigmoid Output = 0.2808 (28.1%) -> Prediction: NOT SPAM
# Email 233: Sigmoid Output = 0.0715 (7.2%) -> Prediction: NOT SPAM
# Email 234: Sigmoid Output = 0.0949 (9.5%) -> Prediction: NOT SPAM
# Email 235: Sigmoid Output = 0.0490 (4.9%) -> Prediction: NOT SPAM
# Email 236: Sigmoid Output = 0.0630 (6.3%) -> Prediction: NOT SPAM
# Email 237: Sigmoid Output = 0.0614 (6.1%) -> Prediction: NOT SPAM
# Email 238: Sigmoid Output = 0.0722 (7.2%) -> Prediction: NOT SPAM
# Email 239: Sigmoid Output = 0.0527 (5.3%) -> Prediction: NOT SPAM
# Email 240: Sigmoid Output = 0.0985 (9.9%) -> Prediction: NOT SPAM
# Email 241: Sigmoid Output = 0.0485 (4.9%) -> Prediction: NOT SPAM
# Email 242: Sigmoid Output = 0.4923 (49.2%) -> Prediction: NOT SPAM
# Email 243: Sigmoid Output = 0.0807 (8.1%) -> Prediction: NOT SPAM
# Email 244: Sigmoid Output = 0.0517 (5.2%) -> Prediction: NOT SPAM
# Email 245: Sigmoid Output = 0.0645 (6.5%) -> Prediction: NOT SPAM
# Email 246: Sigmoid Output = 0.0912 (9.1%) -> Prediction: NOT SPAM
# Email 247: Sigmoid Output = 0.0710 (7.1%) -> Prediction: NOT SPAM
# Email 248: Sigmoid Output = 0.2497 (25.0%) -> Prediction: NOT SPAM
# Email 249: Sigmoid Output = 0.0809 (8.1%) -> Prediction: NOT SPAM
# Email 250: Sigmoid Output = 0.0746 (7.5%) -> Prediction: NOT SPAM
# Email 251: Sigmoid Output = 0.1033 (10.3%) -> Prediction: NOT SPAM
# Email 252: Sigmoid Output = 0.1068 (10.7%) -> Prediction: NOT SPAM
# Email 253: Sigmoid Output = 0.0548 (5.5%) -> Prediction: NOT SPAM
# Email 254: Sigmoid Output = 0.3190 (31.9%) -> Prediction: NOT SPAM
# Email 255: Sigmoid Output = 0.0510 (5.1%) -> Prediction: NOT SPAM
# Email 256: Sigmoid Output = 0.3799 (38.0%) -> Prediction: NOT SPAM
# Email 257: Sigmoid Output = 0.2552 (25.5%) -> Prediction: NOT SPAM
# Email 258: Sigmoid Output = 0.0713 (7.1%) -> Prediction: NOT SPAM
# Email 259: Sigmoid Output = 0.0660 (6.6%) -> Prediction: NOT SPAM
# Email 260: Sigmoid Output = 0.1209 (12.1%) -> Prediction: NOT SPAM
# Email 261: Sigmoid Output = 0.0841 (8.4%) -> Prediction: NOT SPAM
# Email 262: Sigmoid Output = 0.7105 (71.1%) -> Prediction: SPAM
# Email 263: Sigmoid Output = 0.0777 (7.8%) -> Prediction: NOT SPAM
# Email 264: Sigmoid Output = 0.0800 (8.0%) -> Prediction: NOT SPAM
# Email 265: Sigmoid Output = 0.1410 (14.1%) -> Prediction: NOT SPAM
# Email 266: Sigmoid Output = 0.1042 (10.4%) -> Prediction: NOT SPAM
# Email 267: Sigmoid Output = 0.0573 (5.7%) -> Prediction: NOT SPAM
# Email 268: Sigmoid Output = 0.0631 (6.3%) -> Prediction: NOT SPAM
# Email 269: Sigmoid Output = 0.0501 (5.0%) -> Prediction: NOT SPAM
# Email 270: Sigmoid Output = 0.3279 (32.8%) -> Prediction: NOT SPAM
# Email 271: Sigmoid Output = 0.0998 (10.0%) -> Prediction: NOT SPAM
# Email 272: Sigmoid Output = 0.0568 (5.7%) -> Prediction: NOT SPAM
# Email 273: Sigmoid Output = 0.0560 (5.6%) -> Prediction: NOT SPAM
# Email 274: Sigmoid Output = 0.0542 (5.4%) -> Prediction: NOT SPAM
# Email 275: Sigmoid Output = 0.0840 (8.4%) -> Prediction: NOT SPAM
# Email 276: Sigmoid Output = 0.1025 (10.2%) -> Prediction: NOT SPAM
# Email 277: Sigmoid Output = 0.0609 (6.1%) -> Prediction: NOT SPAM
# Email 278: Sigmoid Output = 0.0584 (5.8%) -> Prediction: NOT SPAM
# Email 279: Sigmoid Output = 0.0890 (8.9%) -> Prediction: NOT SPAM
# Email 280: Sigmoid Output = 0.0492 (4.9%) -> Prediction: NOT SPAM
# Email 281: Sigmoid Output = 0.1068 (10.7%) -> Prediction: NOT SPAM
# Email 282: Sigmoid Output = 0.0412 (4.1%) -> Prediction: NOT SPAM
# Email 283: Sigmoid Output = 0.0643 (6.4%) -> Prediction: NOT SPAM
# Email 284: Sigmoid Output = 0.3106 (31.1%) -> Prediction: NOT SPAM
# Email 285: Sigmoid Output = 0.0405 (4.1%) -> Prediction: NOT SPAM
# Email 286: Sigmoid Output = 0.0468 (4.7%) -> Prediction: NOT SPAM
# Email 287: Sigmoid Output = 0.0695 (7.0%) -> Prediction: NOT SPAM
# Email 288: Sigmoid Output = 0.0611 (6.1%) -> Prediction: NOT SPAM
# Email 289: Sigmoid Output = 0.0709 (7.1%) -> Prediction: NOT SPAM
# Email 290: Sigmoid Output = 0.0881 (8.8%) -> Prediction: NOT SPAM
# Email 291: Sigmoid Output = 0.0362 (3.6%) -> Prediction: NOT SPAM
# Email 292: Sigmoid Output = 0.0949 (9.5%) -> Prediction: NOT SPAM
# Email 293: Sigmoid Output = 0.0810 (8.1%) -> Prediction: NOT SPAM
# Email 294: Sigmoid Output = 0.1298 (13.0%) -> Prediction: NOT SPAM
# Email 295: Sigmoid Output = 0.0613 (6.1%) -> Prediction: NOT SPAM
# Email 296: Sigmoid Output = 0.0703 (7.0%) -> Prediction: NOT SPAM
# Email 297: Sigmoid Output = 0.6461 (64.6%) -> Prediction: SPAM
# Email 298: Sigmoid Output = 0.0618 (6.2%) -> Prediction: NOT SPAM
# Email 299: Sigmoid Output = 0.6482 (64.8%) -> Prediction: SPAM
# Email 300: Sigmoid Output = 0.0704 (7.0%) -> Prediction: NOT SPAM

# %%
print("\n" + "="*60 + "\nSample test message, true label, spam-probability:\n")
for i in range(5):
    msg = sample_messages.iloc[i]
    true_label = "SPAM" if y_test.reset_index(drop=True).iloc[i]==1 else "NOT SPAM"
    spam_prob = probabilities[i][1]
    print(f"Message {i+1} (True: {true_label}, Prob(spam)={spam_prob:.3f}):\n  {msg}\n")
# Out:
# ============================================================
# Sample test message, true label, spam-probability:
#
# Message 1 (True: NOT SPAM, Prob(spam)=0.060):
#   Will be out of class in a few hours. Sorry
#
# Message 2 (True: NOT SPAM, Prob(spam)=0.059):
#   Yup i thk they r e teacher said that will make my face look longer. Darren ask me not 2 cut too short.
#
# Message 3 (True: NOT SPAM, Prob(spam)=0.043):
#   Yar i wanted 2 scold u yest but late already... I where got zhong se qing you? If u ask me b4 he ask me then i'll go out w u all lor. N u still can act so real.
#
# Message 4 (True: NOT SPAM, Prob(spam)=0.021):
#   I know where the  &lt;#&gt;  is, I'll be there around 5
#
# Message 5 (True: NOT SPAM, Prob(spam)=0.083):
#   Nothing just getting msgs by dis name wit different no's..
